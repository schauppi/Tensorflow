# %%
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf
import pandas as pd

# %%
bitcoin = yf.Ticker("BTC-EUR") #Bitcoin 
atx = yf.Ticker("^ATX") #Austrian Traded Index
bldp = yf.Ticker("BLDP") # Ballard Power Systems
nel = yf.Ticker("D7G.F") # Nel Asa
plug = yf.Ticker("PUN.F") #Plug Power Inc
nvda = yf.Ticker("NVDA") #Nvidia
voe = yf.Ticker("VOE.VI") #Voestalpine
tesla = yf.Ticker("TL0.F") #Tesla Inc
intel = yf.Ticker("INTC") #Intel Corp
apple = yf.Ticker("AAPL") #Apple
msci = yf.Ticker("EUNL.HM") #Ishsii-Core MSCI WLD ETF
artf = yf.Ticker("XMLD.BE") #Artificial Intelligence ETF
isr = yf.Ticker("QDVM.F") #iShares Israel ETF
alib = yf.Ticker("AHLA.F") #Alibaba
alphab = yf.Ticker("ABEA.F") #Alphabet

# %%
#bitcoin.info

# %%
hist_btc = bitcoin.history(period="max")
hist_atx = atx.history(period="max")
hist_bldp =

# %%
btc_data = hist_btc[["Open", "High", "Low", "Close", "Volume"]]
atx_data = hist_atx[["Open", "High", "Low", "Close", "Volume"]]

# %%
mpf.plot(atx_data, type="candle", style="charles", title="Ausrian Traded Index", ylabel="Price €", volume=True, ylabel_lower="Market Volume", mav=2, figratio=(24,10))

# %%
mpf.plot(btc_data, type="candle", style="charles", title="Bitcoin", ylabel="Price €", volume=True, ylabel_lower="Market Volume", mav=2, figratio=(24,10))
